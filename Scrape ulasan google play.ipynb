# %%
from google_play_scraper import Sort, reviews_all
import pandas as pd
import numpy as np

# %%
from google_play_scraper import Sort, reviews

# %%
result, continuation_token = reviews(
    'com.tokopedia.tkpd',
    lang='id', # defaults to 'en'
    country='id', # defaults to 'us'
    sort=Sort.NEWEST, # defaults to Sort.NEWEST
    count=1000, # defaults to 100
    filter_score_with='' # defaults to None(means all score)
)

# %%
print(result)
app_reviews_df = pd.DataFrame(result)
app_reviews_df.to_csv('E:/tokopediarating.csv', index=None, header=True)
# Out:
# [{'reviewId': '5522d10e-e7f8-41eb-a31f-704f592fb704', 'userName': 'Ade Yovana Sari', 'userImage': 'https://play-lh.googleusercontent.com/a-/ACB-R5SYvZ8ZPALLqPr2qLUKHy2DHUtGdCSnwndtG34BwA', 'content': 'Gratis ongkir sangat tidak sesuai, biaya tambah banyak, pengiriman sangat sangat lama. Percuma bayar lebih pake pengiriman reguler, mending pake kargo. Sudah bbrp kali produk jadi tidak bisa digunakan sesuai rencana karena telatnya pengiriman. Trims toped.', 'score': 1, 'thumbsUpCount': 196, 'reviewCreatedVersion': '3.217', 'at': datetime.datetime(2023, 5, 13, 12, 26, 48), 'replyContent': 'Halo Toppers, terima kasih atas rating yang kamu berikan. Kami akan terus melakukan perkembangan pada aplikasi Tokopedia untuk terus memberikan keamanan dan kenyamanan Toppers dalam bertransaksi. Silakan sampaikan kritik/saran atau kendala transaksi kamu dengan menghubungi Tokopedia Care melalui tkp.me/supportMainapps.', 'repliedAt': datetime.datetime(2023, 5, 13, 13, 4, 5), 'appVersion': '3.217'}, {'reviewId': 'dfadd18c-6175-42cb-bd2a-b0b5c8833b59', 'userName': 'Dessy Wulandari Eka Putri', 'userImage': 'https://play-lh.googleusercontent.com/a-/ACB-R5QHxUYHsXIKzpP9lZUjj60HEoK8Yf6GsW9uZ3Akqw', 'content': 'Zonk. Aplikasi nya ok tapi saya yang belum pernah transaksi token listrik ketika transaksi pertama tidak bisa menggunakan promo yg ada (katanya sudah pernah dipakai).Biaya penangganan 1000 dan biaya jasa tapi pelayanan zonk . Cashback yg jarang ada dan seringnya ketika ada cashback tidak masuk ketika transaksi selesai (ngapain bilang ada cashback kalo ternyata zonk). Harusnya bisa ada review untuk jasa ekspedisi (bukan cuma toko dan barang) . Buruk sekali tidak berkembang malah mundur mutunya', 'score': 1, 'thumbsUpCount': 594, 'reviewCreatedVersion': '3.217', 'at': datetime.datetime(2023, 5, 10, 14, 6, 24), 'replyContent': 'Hai Kak Dessy , mohon maaf atas kendala yang Kakak alami ya Kak, Kritik dan saran dari Kakak menjadi dasar pengembangan sistem/produk ini untuk menjadi lebih baik lagi.  Jika Kakak mengalami kendala silahkan Kakak bisa melakukan pelaporan melalui tkp.me/supportMainapps agar kami bantu pengecekan kendalannya lebih lanjut ya Kak :) -NF', 'repliedAt': datetime.datetime(2022, 9, 21, 4, 37, 56), 'appVersion': '3.217'}, {'reviewId': 'bdd45c5c-45df-4526-bbd6-e313e4bdb046', 'userName': 'Diva Farah Lumaya Sabina', 'userImage': 'https://play-lh.googleusercontent.com/a-/ACB-R5Sp8YP533GOMbVBcWTlnttpsncwVL8bQcmJlRiByg', 'content': 'Saat checkout barang, total keseluruhan belanja bukannya langsung diliatin semuanya malah harus liat Invoice dulu, kesan pertama memakai Tokopedia jadi jelek. Apalagi ditambah dengan kenaikan Biaya Layanan Aplikasi, duh. Juga sekarang tidak bisa menggabungkan 2 Voucher.', 'score': 3, 'thumbsUpCount': 67, 'reviewCreatedVersion': '3.217', 'at': datetime.datetime(2023, 5, 12, 14, 29, 33), 'replyContent': 'Makasih atas ratingnya, Toppers. Jika kamu memiliki kritik/saran atau kendala transaksi, silakan hubungi Tokopedia Care melalui tkp.me/supportMainapps ya. Besar harapan kami, ke depannya Toppers bisa mendapat pengalaman bertransaksi yang lebih baik lagi di Tokopedia.', 'repliedAt': datetime.datetime(2023, 5, 12, 15, 4, 28), 'appVersion': '3.217'}, {'reviewId': '5f0d32d9-94f1-45d6-bdb0-059bd5e58376', 'userName': 'Nevil Burn', 'userImage': 'https://play-lh.googleusercontent.com/a-/ACB-R5Tb1rCbXi_ofVUN5vOFLywXIERt-dBTECia_7gnPw', 'content': 'Kenapa tokopedia masih menggunakan jasa sicepet dalam gratis ongkir. Sementara si cepat sudah tidak sperti dulu, dan barang yg di kirim selalu di teruskan ke patner karena tidak adanya kurir. Dan ini makan waktu sampe belasan hari, jadi untuk sementara sy selaku buyer tetap di toped, instal dan beralih ke apk lain dulu. Sy rasa semua orang pasti mencari kenyamanan.', 'score': 1, 'thumbsUpCount': 8, 'reviewCreatedVersion': '3.215', 'at': datetime.datetime(2023, 5, 14, 16, 59, 6), 'replyContent': 'Halo Toppers, terima kasih atas rating yang kamu berikan. Kami akan terus melakuka ...
